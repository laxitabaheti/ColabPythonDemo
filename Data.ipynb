# %% [markdown]
# <a href="https://colab.research.google.com/github/laxitabaheti/ColabPythonDemo/blob/main/Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/drive/MyDrive/winequality-red.csv", sep=";")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 1               7.8             0.880         0.00  ...       0.68      9.8        5
# 2               7.8             0.760         0.04  ...       0.65      9.8        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# ...

# %%
x1=df["fixed acidity"]
y1=df["volatile acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("volatile acidity")

x1=df["fixed acidity"]
y1=df["residual sugar"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("residual sugar")

x1=df["fixed acidity"]
y1=df["citric acid"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("citric acid")

x1=df["fixed acidity"]
y1=df["chlorides"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("chlorides")

x1=df["fixed acidity"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("free sulfur dioxide")

x1=df["fixed acidity"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("total sulfur dioxide")

x1=df["fixed acidity"]
y1=df["density"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("residual sugar")

x1=df["fixed acidity"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("pH")

x1=df["fixed acidity"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("sulphates")

x1=df["fixed acidity"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("alcohol")

x1=df["fixed acidity"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("quality")

plt.show()

# %% [markdown]
# Graph-7 : with increase in fixed acidity residual sugar increases
#
# Graph 8 : with increase in fixed acidity pH decreases

# %%
x1=df["volatile acidity"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("fixed acidity")

x1=df["volatile acidity"]
y1=df["residual sugar"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("residual sugar")

x1=df["volatile acidity"]
y1=df["citric acid"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("citric acid")

x1=df["volatile acidity"]
y1=df["chlorides"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("chlorides")

x1=df["volatile acidity"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("free sulfur dioxide")

x1=df["volatile acidity"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("total sulfur dioxide")

x1=df["volatile acidity"]
y1=df["density"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("density")

x1=df["volatile acidity"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("pH")

x1=df["volatile acidity"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("sulphates")

x1=df["volatile acidity"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("alcohol")

x1=df["volatile acidity"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("quality")

plt.show()

# %% [markdown]
# Graph

# %%
x1=df["citric acid"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["residual sugar"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["chlorides"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["density"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)


plt.tight_layout()
plt.show()

# %%
x1=df["residual sugar"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["chlorides"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["density"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["chlorides"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["density"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["free sulfur dioxide"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["chlorides"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["density"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["total sulfur dioxide"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["chlorides"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["density"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["density"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["chlorides"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["pH"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["chlorides"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["density"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["sulphates"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["chlorides"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["density"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["pH"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["alcohol"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["chlorides"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["density"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["pH"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["sulphates"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["quality"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["chlorides"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["density"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["pH"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["sulphates"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["alcohol"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
df.keys()
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
k=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']

def function(x,y):
  z=pearsonr(x,y)
  return z
for i in k:
  for j in k:
    if i==j:
      print(" ")
    else:
      x=df[i]
      y=df[j]
      M=function(x,y)
      print(i,j)
      print(function(x,y))

# %%
k=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']
from scipy.stats import pearsonr


def function(x,y):
  z = pearsonr(x,y)
  return z


L=[]

for i in k:
  for j in k:
    if i==j:
      print(" ")
    else:
      x=df[i] 
      y=df[j]
      M=function(x,y)
      L.append(M)
      print(i,j)
      print(function(x,y))

# %% [markdown]
# the **pearson rank** between these quantities are : -
#
# - fixed acidity  and citric acid ( 0.6717034347641061 )
# - fixed acidity and density ( 0.6680472921189743 )
# - free sulfur dioxide and total sulfur dioxide ( 0.6676664504810215 )
# - alcohol and quality ( 0.47616632400113607 )
# - fixed acidity and pH ( - 0.6829781945685314 )
# - volatile acidity and citric acid ( - 0.55249568455958 )
# - pH and  citric acid ( - 0.5419041447395097 )
# - alcohol and density ( - 0.49617977024170107 )
#
# ###Pearson Rank###
#
# Rank varies between - 1 to + 1.
#
#    *  +1 = strong positive relation between two variables
#    *  -1 = strong negative relation between two variables
#    * 0 =  no relation
#
# positive relation
# - fixed acidity  and citric acid ( x=0.6717034347641061 )
# - fixed acidity and density ( 0.6680472921189743 )
# - free sulfur dioxide and total sulfur dioxide ( 0.6676664504810215 )
# - alcohol and quality ( 0.47616632400113607 )
#
# negative relation
# - fixed acidity and pH ( - 0.6829781945685314 )
# - volatile acidity and citric acid ( - 0.55249568455958 )
# - pH and  citric acid ( - 0.5419041447395097 )
# - alcohol and density ( - 0.49617977024170107 )

# %%
x=df['fixed acidity']
y=df["citric acid"]
plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()

x=df['fixed acidity']
y=df["density"]

plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()

x=df['fixed acidity']
y=df["pH"]

plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()

# %%
x=df['alcohol']
y=df["density"]
plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()


x=df['alcohol']
y=df["quality"]
plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()


x=df['pH']
y=df["citric acid"]
plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()


x=df['volatile acidity']
y=df["citric acid"]
plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()
    

x=df['free sulfur dioxide']
y=df["total sulfur dioxide"]
plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()

# %%
k=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']
from scipy.stats import pearsonr


def function(x,y):
  z = pearsonr(x,y)
  return z


L=[]

for i in k:
  for j in k:
    if i!=j:
      x=df[i] 
      y=df[j]
      M=function(x,y)
      Z=(i,j)
      L.append(Z)
      L.append(M)
      print(i,j)
      print(function(x,y))
    else:
      print("next")

# %%
len(L)
# Out:
# 264

# %%
import pandas as pd
P=pd.DataFrame(L)
P
# Out:
#                  0               1
# 0                0               0
# 1        -0.256131     2.27672e-25
# 2    fixed acidity     citric acid
# 3         0.671703    2.53532e-210
# 4    fixed acidity  residual sugar
# ..             ...             ...
# 259     -0.0577314       0.0209628
# 260        quality       sulphates
# 261       0.251397     1.80209e-24
# 262        quality         alcohol
# 263       0.476166     2.83148e-91
#
# [264 rows x 2 columns]

# %%
keys_name=[]
keys_values=[]
for i in range(263):
  if i==0:
    keys_name.append(L[i])
  elif i%2==0:
    keys_name.append(L[i])
  else:
    keys_values.append(L[i])



keys_name
keys_values

# %%
df = pd.DataFrame(list(zip(keys_name, keys_values)),
               columns =['Name', 'values'])

df["values"]
# Out:
# 0      (-0.2561308947703821, 2.2767204431779706e-25)
# 1       (0.671703434764106, 2.5353210618214457e-210)
# 2       (0.11477672449492143, 4.199464867686219e-06)
# 3      (0.09370518632130542, 0.00017517459785438793)
# 4      (-0.15379419286482512, 6.335579450533808e-10)
#                            ...
# 126     (-0.05065605724427638, 0.042833979508175565)
# 127     (-0.18510028892653785, 8.62170342366267e-14)
# 128    (-0.1749192277833501, 1.8749566520107985e-12)
# 129     (-0.05773139120538214, 0.020962778651490887)
# 130    (0.25139707906926123, 1.8020884534539657e-24)
# Name: values, Length: 131, dtype: object
